# %%
from rdkit.Chem import AllChem as ch
from rdkit.Chem import Draw as d

# %%
suppl = ch.SDMolSupplier('../data/drugbank.sdf')
mols = [x for x in suppl if x is not None]

# %%
pattern = ch.MolFromSmarts('[CX3](=O)[OX2H1]')
molecule1 = ch.MolFromSmiles('CCO')

# test if one molecule contains given SMARTS pattern
molecule1.HasSubstructMatch(pattern)
# Out:
# False

# %%
molecule2 = ch.MolFromSmiles('c1ccccc1O')
molecule2.HasSubstructMatch(pattern)
# Out:
# False

# %%
matching_molecules = [m for m in mols if m.HasSubstructMatch(pattern)]

# %%
len(mols)
# Out:
# 7110

# %%
len(matching_molecules)
# Out:
# 1634

# %%
result = [m for m in matching_molecules[:10]]

# %%
map(ch.Compute2DCoords, result)
img = d.MolsToGridImage(result, kekulize=False, subImgSize=(400,400),
                        legends=[mol.GetProp("GENERIC_NAME") for mol in result])

# %%
img
# Out:
# <PIL.Image.Image image mode=RGBA size=1200x1600 at 0x7F71D573D518>
